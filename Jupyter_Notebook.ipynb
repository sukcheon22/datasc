# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Data Science Course

# %% [markdown]
# Author: Quach Duong

# %% [markdown]
# Objectives:
# + Python
# + Java
# + SQL

# %% [markdown]
# Hello, my name is Duong. I am 20 years old.

# %% [markdown]
# Data Sciene languages:
# Python
# R
# SQL
# Java
# Julia

# %% [markdown]
# Data Science Libraries: NumPy, Scipy, Pandas, Keras, Scikit-Learn, TensorFlow, Matplotlib, Seaborn

# %% [markdown]
# | Data Science Tools |
# | --- |
# | MySQL |
# | Apache Airflow |
# | mongoDB |
# | Apache Spark |

# %% [markdown]
# 1 + 1 = 2
# 2 + 5 = 7

# %%
print (2 * 3)
print (1 + 2)
# Out:
# 6
# 3

# %%
minutes = 30
hours = minutes / 60
print (hours)
# Out:
# 0.5
